# %%
import pandas as pd

# %%
df = pd.read_excel('mbta.xlsx')

# %%
df.head(50)
# Out:
#     MBTA Avg Weekday Unlinked Passenger Trips (thousands)         Unnamed: 1  \
# 0                                                 NaN                   mode
# 1                                                 1.0       All Modes by Qtr
# 2                                                 2.0                   Boat
# 3                                                 3.0                    Bus
# 4                                                 4.0          Commuter Rail
# 5                                                 5.0             Heavy Rail
# 6                                                 6.0             Light Rail
# 7                                                 7.0           Pct Chg / Yr
# 8                                                 8.0            Private Bus
# 9                                                 9.0                   RIDE
# 10                                               10.0      Trackless Trolley
# ...

# %%
df.shape
# Out:
# (12, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 60 columns):
# MBTA Avg Weekday Unlinked Passenger Trips (thousands)    11 non-null float64
# Unnamed: 1                                               12 non-null object
# Unnamed: 2                                               11 non-null object
# Unnamed: 3                                               11 non-null object
# Unnamed: 4                                               12 non-null object
# Unnamed: 5                                               11 non-null object
# Unnamed: 6                                               11 non-null object
# Unnamed: 7                                               12 non-null object
# Unnamed: 8                                               11 non-null object
# Unnamed: 9                                               11 non-null object
# Unnamed: 10                                              12 non-null object
# ...

# %%
def tgrp(df):
    df = df.drop('MBTA Avg Weekday Unlinked Passenger Trips (thousands)', axis=1)
    return df.reset_index(drop=True).T

df.groupby('MBTA Avg Weekday Unlinked Passenger Trips (thousands)').apply(tgrp).unstack()
# Out:
#                                                                     0  \
#                                                            Unnamed: 1
# MBTA Avg Weekday Unlinked Passenger Trips (thou...
# 1.0                                                  All Modes by Qtr
# 2.0                                                              Boat
# 3.0                                                               Bus
# 4.0                                                     Commuter Rail
# 5.0                                                        Heavy Rail
# 6.0                                                        Light Rail
# 7.0                                                      Pct Chg / Yr
# 8.0                                                       Private Bus
# 9.0                                                              RIDE
# 10.0                                                Trackless Trolley
# 11.0                                                            TOTAL
#
# ...

# %%
df
# Out:
#     MBTA Avg Weekday Unlinked Passenger Trips (thousands)         Unnamed: 1  \
# 0                                                 NaN                   mode
# 1                                                 1.0       All Modes by Qtr
# 2                                                 2.0                   Boat
# 3                                                 3.0                    Bus
# 4                                                 4.0          Commuter Rail
# 5                                                 5.0             Heavy Rail
# 6                                                 6.0             Light Rail
# 7                                                 7.0           Pct Chg / Yr
# 8                                                 8.0            Private Bus
# 9                                                 9.0                   RIDE
# 10                                               10.0      Trackless Trolley
# ...

# %%
df = pd.read_excel('mbta.xlsx')

# %%
df.head(50)
# Out:
#     MBTA Avg Weekday Unlinked Passenger Trips (thousands)         Unnamed: 1  \
# 0                                                 NaN                   mode
# 1                                                 1.0       All Modes by Qtr
# 2                                                 2.0                   Boat
# 3                                                 3.0                    Bus
# 4                                                 4.0          Commuter Rail
# 5                                                 5.0             Heavy Rail
# 6                                                 6.0             Light Rail
# 7                                                 7.0           Pct Chg / Yr
# 8                                                 8.0            Private Bus
# 9                                                 9.0                   RIDE
# 10                                               10.0      Trackless Trolley
# ...

# %%
df_T = df.T

# %%
df_T
# Out:
#                                                           0                 1  \
# MBTA Avg Weekday Unlinked Passenger Trips (thou...      NaN                 1
# Unnamed: 1                                             mode  All Modes by Qtr
# Unnamed: 2                                          2007-01               NaN
# Unnamed: 3                                          2007-02               NaN
# Unnamed: 4                                          2007-03           1187.65
# Unnamed: 5                                          2007-04               NaN
# Unnamed: 6                                          2007-05               NaN
# Unnamed: 7                                          2007-06           1245.96
# Unnamed: 8                                          2007-07               NaN
# Unnamed: 9                                          2007-08               NaN
# Unnamed: 10                                         2007-09           1256.57
# ...

# %%
df_T.set_index('MBTA avg Weekday Unlinked Passenger Trips(thousands)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-68753613de7b> in <module>
# ----> 1 df_T.set_index('MBTA avg Weekday Unlinked Passenger Trips(thousands)')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['MBTA avg Weekday Unlinked Passenger Trips(thousands)'] are in the columns"

# %%
df_T.drop('MBTA Avg Weekday Unlinked Passenger Trips (thousands)', axis = 0,inplace = True)

# %%
df_T.head(50)
# Out:
#                    0                 1      2        3              4  \
# Unnamed: 1      mode  All Modes by Qtr   Boat      Bus  Commuter Rail
# Unnamed: 2   2007-01               NaN      4  335.819          142.2
# Unnamed: 3   2007-02               NaN    3.6  338.675          138.5
# Unnamed: 4   2007-03           1187.65     40  339.867          137.7
# Unnamed: 5   2007-04               NaN    4.3  352.162          139.5
# Unnamed: 6   2007-05               NaN    4.9  354.367            139
# Unnamed: 7   2007-06           1245.96    5.8  350.543            143
# Unnamed: 8   2007-07               NaN  6.521  357.519        142.391
# Unnamed: 9   2007-08               NaN  6.572  355.479        142.364
# Unnamed: 10  2007-09           1256.57  5.469  372.598        143.051
# Unnamed: 11  2007-10               NaN  5.145  368.847        146.542
# Unnamed: 12  2007-11               NaN  3.763  330.826        145.089
# ...

# %%
df_T.reset_index()
# Out:
#           index        0                 1      2        3              4  \
# 0    Unnamed: 1     mode  All Modes by Qtr   Boat      Bus  Commuter Rail
# 1    Unnamed: 2  2007-01               NaN      4  335.819          142.2
# 2    Unnamed: 3  2007-02               NaN    3.6  338.675          138.5
# 3    Unnamed: 4  2007-03           1187.65     40  339.867          137.7
# 4    Unnamed: 5  2007-04               NaN    4.3  352.162          139.5
# 5    Unnamed: 6  2007-05               NaN    4.9  354.367            139
# 6    Unnamed: 7  2007-06           1245.96    5.8  350.543            143
# 7    Unnamed: 8  2007-07               NaN  6.521  357.519        142.391
# 8    Unnamed: 9  2007-08               NaN  6.572  355.479        142.364
# 9   Unnamed: 10  2007-09           1256.57  5.469  372.598        143.051
# 10  Unnamed: 11  2007-10               NaN  5.145  368.847        146.542
# 11  Unnamed: 12  2007-11               NaN  3.763  330.826        145.089
# ...

# %%
df_T.columns
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df_T.drop(0, index = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f655f5818d22> in <module>
# ----> 1 df_T.drop(0, index = 1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3897             if index is not None or columns is not None:
#    3898                 raise ValueError(
# -> 3899                     "Cannot specify both 'labels' and " "'index'/'columns'"
#    3900                 )
#    3901             axis_name = self._get_axis_name(axis)
#
# ValueError: Cannot specify both 'labels' and 'index'/'columns'

# %%
df_T.index
import numpy as np
df_T.set_index(np.arange(59), inplace = True)

# %%
head = df_T.iloc[0]

# %%
head
# Out:
# 0                  mode
# 1      All Modes by Qtr
# 2                  Boat
# 3                   Bus
# 4         Commuter Rail
# 5            Heavy Rail
# 6            Light Rail
# 7          Pct Chg / Yr
# 8           Private Bus
# 9                  RIDE
# 10    Trackless Trolley
# 11                TOTAL
# Name: Unnamed: 1, dtype: object

# %%
df_T.columns = head

# %%
df_T.head(50)
# Out:
# Unnamed: 1     mode  All Modes by Qtr   Boat      Bus  Commuter Rail  \
# 0              mode  All Modes by Qtr   Boat      Bus  Commuter Rail
# 1           2007-01               NaN      4  335.819          142.2
# 2           2007-02               NaN    3.6  338.675          138.5
# 3           2007-03           1187.65     40  339.867          137.7
# 4           2007-04               NaN    4.3  352.162          139.5
# 5           2007-05               NaN    4.9  354.367            139
# 6           2007-06           1245.96    5.8  350.543            143
# 7           2007-07               NaN  6.521  357.519        142.391
# 8           2007-08               NaN  6.572  355.479        142.364
# 9           2007-09           1256.57  5.469  372.598        143.051
# 10          2007-10               NaN  5.145  368.847        146.542
# 11          2007-11               NaN  3.763  330.826        145.089
# 12          2007-12           1216.89  2.985   312.92        141.585
# ...

# %%
df_T.drop(0, axis = 0, inplace = True)

# %%
df_T.head()
# Out:
# Unnamed: 1     mode All Modes by Qtr Boat      Bus Commuter Rail Heavy Rail  \
# 1           2007-01              NaN    4  335.819         142.2    435.294
# 2           2007-02              NaN  3.6  338.675         138.5    448.271
# 3           2007-03          1187.65   40  339.867         137.7    458.583
# 4           2007-04              NaN  4.3  352.162         139.5    472.201
# 5           2007-05              NaN  4.9  354.367           139    474.579
#
# Unnamed: 1 Light Rail Pct Chg / Yr Private Bus RIDE Trackless Trolley    TOTAL
# 1             227.231         0.02       4.772  4.9            12.757  1166.97
# 2             240.262        -0.04       4.417    5            12.913  1191.64
# 3             241.444        0.114       4.574  5.5            13.057  1204.72
# 4             255.557       -0.002       4.542  5.4            13.444  1247.11
# 5             248.262        0.049       4.768  5.4            13.479  1244.76

# %%
df_T.info()
df_T.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1 to 58
# Data columns (total 12 columns):
# mode                 58 non-null object
# All Modes by Qtr     19 non-null object
# Boat                 58 non-null object
# Bus                  58 non-null object
# Commuter Rail        58 non-null object
# Heavy Rail           58 non-null object
# Light Rail           58 non-null object
# Pct Chg / Yr         58 non-null object
# Private Bus          58 non-null object
# RIDE                 58 non-null object
# Trackless Trolley    58 non-null object
# TOTAL                58 non-null object
# dtypes: object(12)
# memory usage: 5.9+ KB
# Unnamed: 1
# mode                  0
# All Modes by Qtr     39
# Boat                  0
# Bus                   0
# Commuter Rail         0
# Heavy Rail            0
# Light Rail            0
# Pct Chg / Yr          0
# Private Bus           0
# RIDE                  0
# Trackless Trolley     0
# TOTAL                 0
# dtype: int64

# %%
df_T.head()
# Out:
# Unnamed: 1     mode All Modes by Qtr Boat      Bus Commuter Rail Heavy Rail  \
# 1           2007-01              NaN    4  335.819         142.2    435.294
# 2           2007-02              NaN  3.6  338.675         138.5    448.271
# 3           2007-03          1187.65   40  339.867         137.7    458.583
# 4           2007-04              NaN  4.3  352.162         139.5    472.201
# 5           2007-05              NaN  4.9  354.367           139    474.579
#
# Unnamed: 1 Light Rail Pct Chg / Yr Private Bus RIDE Trackless Trolley    TOTAL
# 1             227.231         0.02       4.772  4.9            12.757  1166.97
# 2             240.262        -0.04       4.417    5            12.913  1191.64
# 3             241.444        0.114       4.574  5.5            13.057  1204.72
# 4             255.557       -0.002       4.542  5.4            13.444  1247.11
# 5             248.262        0.049       4.768  5.4            13.479  1244.76

# %%
df_T['mode'].isna().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', 100)

# %%
df_T.head()
# Out:
# Unnamed: 1     mode All Modes by Qtr Boat      Bus Commuter Rail Heavy Rail  \
# 1           2007-01              NaN    4  335.819         142.2    435.294
# 2           2007-02              NaN  3.6  338.675         138.5    448.271
# 3           2007-03          1187.65   40  339.867         137.7    458.583
# 4           2007-04              NaN  4.3  352.162         139.5    472.201
# 5           2007-05              NaN  4.9  354.367           139    474.579
#
# Unnamed: 1 Light Rail Pct Chg / Yr Private Bus RIDE Trackless Trolley    TOTAL
# 1             227.231         0.02       4.772  4.9            12.757  1166.97
# 2             240.262        -0.04       4.417    5            12.913  1191.64
# 3             241.444        0.114       4.574  5.5            13.057  1204.72
# 4             255.557       -0.002       4.542  5.4            13.444  1247.11
# 5             248.262        0.049       4.768  5.4            13.479  1244.76

# %%
df_T['All Modes by Qtr'].fillna(value = df_T['All Modes by Qtr'].mean(), inplace = True)

# %%
df_T['Boat'].fillna(value = df_T['Boat'].mean(), inplace = True)

# %%
df_T['Bus'].fillna(value = df_T['Bus'].mean(), inplace = True)

# %%
df_T['Commuter Rail'].fillna(value = df_T['Commuter Rail'].mean(), inplace = True)

# %%
df_T['Heavy Rail'].fillna(value = df_T['Heavy Rail'].mean(), inplace = True)

# %%
df_T['Light Rail'].fillna(value = df_T['Light Rail'].mean(), inplace = True)

# %%
df_T['Pct Chg / Yr'].fillna(value = df_T['Pct Chg / Yr'].mean(), inplace = True)
df_T['Private Bus'].fillna(value = df_T['Private Bus'].mean(), inplace = True)
df_T['Heavy Rail'].fillna(value = df_T['Heavy Rail'].mean(), inplace = True)
df_T['RIDE'].fillna(value = df_T['RIDE'].mean(), inplace = True)
df_T['Trackless Trolley'].fillna(value = df_T['Trackless Trolley'].mean(), inplace = True)
df_T['TOTAL'].fillna(value = df_T['TOTAL'].mean(), inplace = True)

# %%
df.head()
# Out:
#    MBTA Avg Weekday Unlinked Passenger Trips (thousands)        Unnamed: 1  \
# 0                                                NaN                  mode
# 1                                                1.0      All Modes by Qtr
# 2                                                2.0                  Boat
# 3                                                3.0                   Bus
# 4                                                4.0         Commuter Rail
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0    2007-01    2007-02    2007-03    2007-04    2007-05    2007-06
# 1        NaN        NaN    1187.65        NaN        NaN    1245.96
# 2          4        3.6         40        4.3        4.9        5.8
# 3    335.819    338.675    339.867    352.162    354.367    350.543
# 4      142.2      138.5      137.7      139.5        139        143
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# ...

# %%
df_T.isna().sum()
# Out:
# Unnamed: 1
# mode                 0
# All Modes by Qtr     0
# Boat                 0
# Bus                  0
# Commuter Rail        0
# Heavy Rail           0
# Light Rail           0
# Pct Chg / Yr         0
# Private Bus          0
# RIDE                 0
# Trackless Trolley    0
# TOTAL                0
# dtype: int64

# %%
# %matplotlib inline
df.plot(kind = 'hist')

# %%
df.plot(kind = 'bar')

# %%
df_T.to_csv('finData.csv')

# %%
df_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1 to 58
# Data columns (total 12 columns):
# mode                 58 non-null object
# All Modes by Qtr     58 non-null float64
# Boat                 58 non-null float64
# Bus                  58 non-null float64
# Commuter Rail        58 non-null float64
# Heavy Rail           58 non-null float64
# Light Rail           58 non-null object
# Pct Chg / Yr         58 non-null float64
# Private Bus          58 non-null float64
# RIDE                 58 non-null float64
# Trackless Trolley    58 non-null float64
# TOTAL                58 non-null float64
# dtypes: float64(10), object(2)
# memory usage: 5.9+ KB
