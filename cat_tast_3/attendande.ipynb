# %%
import pandas as pd

# %%
df = pd.read_excel('attendance.xls',na_values=['‡','(†)'])

# %%
df.head(50)
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   1
# 3                              United States ........
# 4                           Alabama .................
# 5                           Alaska ..................
# 6                           Arizona .................
# 7                           Arkansas ................
# 8                           California ..............
# 9                                                 NaN
# 10                          Colorado ................
# 11                          Connecticut .............
# 12                          Delaware ................
# 13                          District of Columbia ....
# ...

# %%
df.shape
# Out:
# (68, 17)

# %%
df.dropna(how = 'all',axis = 0, inplace = True)

# %%
df.isna().sum()
# Out:
# Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08     2
# Unnamed: 1                                                                                                                                                                        4
# Unnamed: 2                                                                                                                                                                        7
# Unnamed: 3                                                                                                                                                                        5
# Unnamed: 4                                                                                                                                                                        7
# ...

# %%
df.head(20)
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   1
# 3                              United States ........
# 4                           Alabama .................
# 5                           Alaska ..................
# 6                           Arizona .................
# 7                           Arkansas ................
# 8                           California ..............
# 10                          Colorado ................
# 11                          Connecticut .............
# 12                          Delaware ................
# 13                          District of Columbia ....
# 14                          Florida .................
# ...

# %%
df['col18'] = df.loc[0:1, :]

# %%
df.head(50)
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   1
# 3                              United States ........
# 4                           Alabama .................
# 5                           Alaska ..................
# 6                           Arizona .................
# 7                           Arkansas ................
# 8                           California ..............
# 10                          Colorado ................
# 11                          Connecticut .............
# 12                          Delaware ................
# 13                          District of Columbia ....
# 14                          Florida .................
# ...

# %%
df.head(20)
df.drop([2], axis = 0, inplace = True)

# %%
df.head(50)
df.drop(['col18'], axis = 1, inplace = True)

# %%
df.head(20)
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 3                              United States ........
# 4                           Alabama .................
# 5                           Alaska ..................
# 6                           Arizona .................
# 7                           Arkansas ................
# 8                           California ..............
# 10                          Colorado ................
# 11                          Connecticut .............
# 12                          Delaware ................
# 13                          District of Columbia ....
# 14                          Florida .................
# 16                          Georgia .................
# 17                          Hawaii ..................
# 18                          Idaho ...................
# ...

# %%
df.columns = ['state', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col_10', 'col_11', 'col_12', 'col_13','col_14', 'col_15','col_16']

# %%
df.head(20)
# Out:
#                         state       col1      col2     col3      col4   col5  \
# 3      United States ........  93.078962  0.218555  6.64470  0.017650  180.0
# 4   Alabama .................  93.812371  1.237261  7.02852  0.065621  180.0
# 5   Alaska ..................  89.917597  1.215976  6.47688  0.049882  180.0
# 6   Arizona .................  89.036961  2.952601  6.43369  0.091917  181.0
# 7   Arkansas ................  91.827111  1.352924  6.88542  0.061468  179.0
# 8   California ..............  93.241017  0.711649  6.24064  0.066364  181.0
# 10  Colorado ................  93.887162  0.440366  7.00761  0.051954  171.0
# 11  Connecticut .............  87.925871  2.984395  6.46655  0.087829  181.0
# 12  Delaware ................  89.770581  1.754942  6.67801  0.089584  181.0
# 13  District of Columbia ....  91.220829  1.269699  6.91375  0.214259  181.0
# 14  Florida .................  92.678174  0.741328  6.42749  0.084127  184.0
# ...

# %%
df['col1'].fillna(value = df['col1'].mean(), inplace = True)

# %%
df['col1'].isna().sum()
# Out:
# 0

# %%
df['col2'].fillna(value = df['col2'].mean(), inplace = True)
df['col3'].fillna(value = df['col3'].mean(), inplace = True)
df['col4'].fillna(value = df['col4'].mean(), inplace = True)
df['col5'].fillna(value = df['col5'].mean(), inplace = True)
df['col6'].fillna(value = df['col6'].mean(), inplace = True)
df['col7'].fillna(value = df['col7'].mean(), inplace = True)
df['col8'].fillna(value = df['col8'].mean(), inplace = True)
df['col9'].fillna(value = df['col9'].mean(), inplace = True)
df['col_10'].fillna(value = df['col_10'].mean(), inplace = True)
df['col_11'].fillna(value = df['col_11'].mean(), inplace = True)
df['col_12'].fillna(value = df['col_12'].mean(), inplace = True)
df['col_13'].fillna(value = df['col_13'].mean(), inplace = True)
df['col_14'].fillna(value = df['col_14'].mean(), inplace = True)
df['col_15'].fillna(value = df['col_15'].mean(), inplace = True)
df['col_16'].fillna(value = df['col_16'].mean(), inplace = True)

# %%
df.isna().sum()
# Out:
# state     0
# col1      0
# col2      0
# col3      0
# col4      0
# col5      0
# col6      0
# col7      0
# col8      0
# col9      0
# col_10    0
# col_11    0
# col_12    0
# col_13    0
# col_14    0
# col_15    0
# col_16    0
# dtype: int64

# %%
df.dtypes
# Out:
# state      object
# col1      float64
#  col2     float64
# col3       object
# col4      float64
# col5       object
# col6      float64
# col7       object
# col8      float64
# col9       object
# col_10    float64
# col_11     object
# col_12    float64
# col_13     object
# col_14    float64
# col_15     object
# col_16    float64
# dtype: object

# %%
df.head(70)
# Out:
#                                                 state       col1      col2  \
# 3                              United States ........  93.078962  0.218555
# 4                           Alabama .................  93.812371  1.237261
# 5                           Alaska ..................  89.917597  1.215976
# 6                           Arizona .................  89.036961  2.952601
# 7                           Arkansas ................  91.827111  1.352924
# 8                           California ..............  93.241017  0.711649
# 10                          Colorado ................  93.887162  0.440366
# 11                          Connecticut .............  87.925871  2.984395
# 12                          Delaware ................  89.770581  1.754942
# 13                          District of Columbia ....  91.220829  1.269699
# 14                          Florida .................  92.678174  0.741328
# ...

# %%
df.columns
# Out:
# Index(['state', 'col1', ' colX', 'col3', 'col4', 'col5', 'col6', 'col7',
#        'col8', 'col9', 'col_10', 'col_11', 'col_12', 'col_13', 'col_14',
#        'col_15', 'col_16'],
#       dtype='object')

# %% [markdown]
# # what is the problem with this col2??

# %%
df.dtypes
# Out:
# state      object
# col1      float64
#  colX     float64
# col3      float64
# col4      float64
# col5      float64
# col6      float64
# col7      float64
# col8      float64
# col9      float64
# col_10    float64
# col_11    float64
# col_12    float64
# col_13    float64
# col_14    float64
# col_15    float64
# col_16    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 3 to 67
# Data columns (total 17 columns):
# state     56 non-null object
# col1      56 non-null float64
# col2      56 non-null float64
# col3      56 non-null float64
# col4      56 non-null float64
# col5      56 non-null float64
# col6      56 non-null float64
# col7      56 non-null float64
# col8      56 non-null float64
# col9      56 non-null float64
# col_10    56 non-null float64
# col_11    56 non-null float64
# col_12    56 non-null float64
# col_13    56 non-null float64
# col_14    56 non-null float64
# col_15    56 non-null float64
# col_16    56 non-null float64
# dtypes: float64(16), object(1)
# memory usage: 7.9+ KB

# %%
df.tail()
# Out:
#                                                 state       col1      col2  \
# 63                          Wyoming .................  92.353008  1.154487
# 64                                   †Not applicable.  92.789499  1.371106
# 65    ‡Reporting standards not met (too few cases).    92.789499  1.371106
# 66  NOTE: Averages reflect data reported by school...  92.789499  1.371106
# 67  SOURCE: U.S. Department of Education, National...  92.789499  1.371106
#
#         col3      col4        col5      col6         col7       col8  \
# 63  6.858670  0.045848  175.000000  1.278829  1200.932300   8.326600
# 64  6.662335  0.076796  178.942308  0.796034  1191.895908  13.881554
# 65  6.662335  0.076796  178.942308  0.796034  1191.895908  13.881554
# 66  6.662335  0.076796  178.942308  0.796034  1191.895908  13.881554
# 67  6.662335  0.076796  178.942308  0.796034  1191.895908  13.881554
#
#          col9    col_10    col_11    col_12     col_13    col_14    col_15  \
# ...

# %%
df.to_csv('attendance.csv')
