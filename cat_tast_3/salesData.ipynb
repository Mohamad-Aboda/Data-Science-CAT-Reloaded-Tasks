# %%
import pandas as pd

# %%
df = pd.read_csv('sales.csv', encoding ='latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
# Unnamed: 0                5000 non-null int64
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_date_time           5000 non-null object
# event_dt                  5000 non-null object
# ...

# %%
pd.get_option('display.max.columns')
# Out:
# 20

# %%
pd.set_option('display.max.columns', None)

# %%
df.head(50)
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 0            1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2            3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3            4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4            5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5            6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7            8  593b910d17913d7101cb  91c03a34b562436efa3c
# 8            9  0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42
# 9           10  93fce8094d89e0a94aac  f6425a3223e73ea6de5a
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 11          12  6adcf8b2dc8a761b22b7  094156ef72361776c8ee
# 12          13  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef
# 13          14  5c7d36b783905ba488f4  34ad0e9254b8f7d1cbe0
# 14          15  e68754d15ef2b8694b26  6e3df9919c998817e1b1
# ...

# %%
df.isna()
# Out:
#       Unnamed: 0  event_id  primary_act_id  secondary_act_id  \
# 0          False     False           False             False
# 1          False     False           False             False
# 2          False     False           False             False
# 3          False     False           False             False
# 4          False     False           False             False
# ...          ...       ...             ...               ...
# 4995       False     False           False             False
# 4996       False     False           False             False
# 4997       False     False           False             False
# 4998       False     False           False             False
# 4999       False     False           False             False
#
#       purch_party_lkup_id  event_name  primary_act_name  secondary_act_name  \
# 0                   False       False             False                True
# 1                   False       False             False               False
# ...

# %%
df.married_ind.isna().sum()
df.child_present_ind.isna().sum()
# Out:
# 4870

# %%
df.shape
# Out:
# (5000, 46)

# %%
df.sales_platform_cd.isna().sum()
# Out:
# 2422

# %%
df.head(50)
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 0            1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2            3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3            4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4            5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5            6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7            8  593b910d17913d7101cb  91c03a34b562436efa3c
# 8            9  0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42
# 9           10  93fce8094d89e0a94aac  f6425a3223e73ea6de5a
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 11          12  6adcf8b2dc8a761b22b7  094156ef72361776c8ee
# 12          13  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef
# 13          14  5c7d36b783905ba488f4  34ad0e9254b8f7d1cbe0
# 14          15  e68754d15ef2b8694b26  6e3df9919c998817e1b1
# ...

# %%
df.shape
# Out:
# (5000, 46)

# %%
df.dropna(axis = 0, how = 'all', subset = ['gndr_cd', 'age_yr', 'income_amt', 'edu_val', 'edu_1st_indv_val', 'edu_2nd_indv_val', 'adults_in_hh_num','married_ind','child_present_ind','home_owner_ind','occpn_val','occpn_1st_val','occpn_2nd_val','dist_to_ven'],inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %%
df.shape
# Out:
# (503, 46)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
df.sales_platform_cd.isna().sum()
# Out:
# 503

# %%
df.drop('sales_platform_cd', axis = 1, inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
df.major_cat_name.nunique()
df.major_cat_name.isna().sum()
df.info()
df.minor_cat_name.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503 entries, 1 to 4997
# Data columns (total 44 columns):
# Unnamed: 0                503 non-null int64
# event_id                  503 non-null object
# primary_act_id            503 non-null object
# secondary_act_id          503 non-null object
# purch_party_lkup_id       503 non-null object
# event_name                503 non-null object
# primary_act_name          503 non-null object
# major_cat_name            503 non-null object
# minor_cat_name            503 non-null object
# la_event_type_cat         503 non-null object
# event_disp_name           503 non-null object
# ticket_text               503 non-null object
# tickets_purchased_qty     503 non-null int64
# trans_face_val_amt        503 non-null float64
# delivery_type_cd          503 non-null object
# event_date_time           503 non-null object
# event_dt                  503 non-null object
# presale_dt                78 non-null object
# ...

# %%
df.minor_cat_name.isna().sum()
df.minor_cat_name.nunique()
df['minor_cat_name'] = df.minor_cat_name.astype('category')
pd.get_dummies(df, columns=['minor_cat_name'], drop_first=True).head()
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15          16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23          24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
#
#         secondary_act_id   purch_party_lkup_id  \
# 1   f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 6   b85143bf51323b72e53c  14af02b72584fa823f85
# 10  b85143bf51323b72e53c  4e4d22890318dae96e6d
# 15  b85143bf51323b72e53c  ebee63b01e98b720aebc
# 23  b85143bf51323b72e53c  7d2d3566e9bfe70ec9ef
#
#                                            event_name  \
# 1       Gorge Camping - dave matthews band - sept 3-7
# 6   Phil Lesh & friends-pnc bank arts center holmd...
# 10  Cricket Pavilion Premier Parking: Earth Wind A...
# 15                        Premier Parking: Toby Keith
# ...

# %%
pd.get_dummies(df, columns=['la_event_type_cat'], drop_first=True).head()
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15          16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23          24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
#
#         secondary_act_id   purch_party_lkup_id  \
# 1   f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 6   b85143bf51323b72e53c  14af02b72584fa823f85
# 10  b85143bf51323b72e53c  4e4d22890318dae96e6d
# 15  b85143bf51323b72e53c  ebee63b01e98b720aebc
# 23  b85143bf51323b72e53c  7d2d3566e9bfe70ec9ef
#
#                                            event_name  \
# 1       Gorge Camping - dave matthews band - sept 3-7
# 6   Phil Lesh & friends-pnc bank arts center holmd...
# 10  Cricket Pavilion Premier Parking: Earth Wind A...
# 15                        Premier Parking: Toby Keith
# ...

# %%
df.trans_face_val_amt.isna().sum()
df.delivery_type_cd.isna().sum()
df.delivery_type_cd
df
# Out:
# 1       TicketFast
# 6       TicketFast
# 10      TicketFast
# 15            Mail
# 23             BWC
#            ...
# 4967          Mail
# 4970          Mail
# 4974    TicketFast
# 4992          Mail
# 4997          Mail
# Name: delivery_type_cd, Length: 503, dtype: object

# %%
pd.get_dummies(df, columns=['delivery_type_cd'], drop_first=True).head()
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15          16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23          24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
#
#         secondary_act_id   purch_party_lkup_id  \
# 1   f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 6   b85143bf51323b72e53c  14af02b72584fa823f85
# 10  b85143bf51323b72e53c  4e4d22890318dae96e6d
# 15  b85143bf51323b72e53c  ebee63b01e98b720aebc
# 23  b85143bf51323b72e53c  7d2d3566e9bfe70ec9ef
#
#                                            event_name  \
# 1       Gorge Camping - dave matthews band - sept 3-7
# 6   Phil Lesh & friends-pnc bank arts center holmd...
# 10  Cricket Pavilion Premier Parking: Earth Wind A...
# 15                        Premier Parking: Toby Keith
# ...

# %%
df.gndr_cd.isna().sum()
df.drop('gndr_cd', axis = 1, inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
df.presale_dt.isna().sum()
# Out:
# 425

# %%
df.drop('presale_dt', axis = 1, inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
mn = df.age_yr.mean()
df['age_yr'].fillna(value = mn , inplace = True)

# %%
mn = df.income_amt.mean()
df['income_amt'].fillna(value = mn , inplace = True)

# %%
df['edu_val'].fillna(value = 'Missing', inplace = True)

# %%
df['edu_1st_indv_val'].fillna(value = 'Missing', inplace = True)
df['edu_2nd_indv_val'].fillna(value = 'Missing', inplace = True)

# %%
mn = df.adults_in_hh_num.mean()
df['adults_in_hh_num'].fillna(value = mn, inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
mn = df.married_ind.mean()

# %%
df['married_ind'].fillna(value = mn , inplace = True)

# %%
df.child_present_ind.fillna(value = df.child_present_ind.mean(), inplace = True)

# %%
df.home_owner_ind.fillna(value = df.home_owner_ind.mean(), inplace = True)

# %%
df.occpn_1st_val.isna().sum()
# Out:
# 426

# %%
df.drop('occpn_1st_val',axis = 1, inplace = True)

# %%
df.occpn_2nd_val.isna().sum()
# Out:
# 440

# %%
df.drop('occpn_2nd_val',axis = 1, inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
df.dist_to_ven.isna().sum()
# Out:
# 180

# %%
df['dist_to_ven'].fillna(value = df.dist_to_ven.mean(), inplace = True)

# %%
df['occpn_val'].isna().sum()
# Out:
# 424

# %%
df['occpn_val'].fillna(value = 'Missing', inplace = True)

# %%
df.head(50)
# Out:
#      Unnamed: 0              event_id        primary_act_id  \
# 1             2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 6             7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 10           11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 15           16  afd7dbe7675fc5480a0c  4b677c3f5bec71eec8d1
# 23           24  179eb086e65ad82d0225  9caaa3cea047cfffa7b3
# 48           49  3ca4efcbc36374aa4161  1a3e9aecd0617706a794
# 49           50  95a7d1ccb5fe10bd037c  1a3e9aecd0617706a794
# 71           72  00e00557718d55826bf0  ea6991e953477c0bb31f
# 75           76  86d498ec819a89b1f843  d769ab09a96be5a0b316
# 79           80  071850b742c7cd68e57b  86548c5bce2089a5d311
# 85           86  6752a309905b3b027656  5a29f349bfe4d595f521
# 93           94  fcd075ec4191081e1c9e  d769ab09a96be5a0b316
# 99          100  e5b1ba0d6665ee414f2b  03cabca4db63531dc982
# 116         117  e46b2cb5a31081de42b0  dcf5dff6a6534968c4d4
# 125         126  16704ed7a8e70cfee64a  4b677c3f5bec71eec8d1
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# event_id                  0
# primary_act_id            0
# secondary_act_id          0
# purch_party_lkup_id       0
# event_name                0
# primary_act_name          0
# major_cat_name            0
# minor_cat_name            0
# la_event_type_cat         0
# event_disp_name           0
# ticket_text               0
# tickets_purchased_qty     0
# trans_face_val_amt        0
# delivery_type_cd          0
# event_date_time           0
# event_dt                  0
# onsale_dt                 5
# sales_ord_create_dttm     0
# sales_ord_tran_dt         0
# print_dt                  1
# timezn_nm                 0
# venue_city                0
# venue_state               0
# venue_postal_cd_sgmt_1    0
# print_flg                 0
# la_valid_tkt_event_flg    0
# fin_mkt_nm                0
# web_session_cookie_val    0
# age_yr                    0
# income_amt                0
# edu_val                   0
# edu_1st_indv_val          0
# ...

# %%
df[df.print_dt.isna()]
# Out:
#       Unnamed: 0              event_id        primary_act_id  \
# 3776        3777  c5e146a5f2459aabc4c9  4b677c3f5bec71eec8d1
#
#           secondary_act_id   purch_party_lkup_id  \
# 3776  e2981973281c70939168  b74f2e8c53fd26ca46d9
#
#                                              event_name primary_act_name  \
# 3776  The Gorge Premier Parking - sasquatch fest may 23    Parking Event
#
#      major_cat_name minor_cat_name la_event_type_cat  \
# 3776           MISC        PARKING           PARKING
#
#                                         event_disp_name  \
# 3776  The Gorge Premier Parking - sasquatch fest may 23
#
#                                             ticket_text  \
# 3776  THIS TICKET IS VALID%FOR PREMIER PARKING ONLY%...
#
#       tickets_purchased_qty  trans_face_val_amt delivery_type_cd  \
# 3776                      1                28.0       TicketFast
#
#           event_date_time    event_dt   onsale_dt sales_ord_create_dttm  \
# ...

# %%
df['print_dt'].fillna(value = 'Missing', inplace = True)

# %%
df['onsale_dt'].fillna(value = 'Missing', inplace = True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# event_id                  0
# primary_act_id            0
# secondary_act_id          0
# purch_party_lkup_id       0
# event_name                0
# primary_act_name          0
# major_cat_name            0
# minor_cat_name            0
# la_event_type_cat         0
# event_disp_name           0
# ticket_text               0
# tickets_purchased_qty     0
# trans_face_val_amt        0
# delivery_type_cd          0
# event_date_time           0
# event_dt                  0
# onsale_dt                 0
# sales_ord_create_dttm     0
# sales_ord_tran_dt         0
# print_dt                  0
# timezn_nm                 0
# venue_city                0
# venue_state               0
# venue_postal_cd_sgmt_1    0
# print_flg                 0
# la_valid_tkt_event_flg    0
# fin_mkt_nm                0
# web_session_cookie_val    0
# age_yr                    0
# income_amt                0
# edu_val                   0
# edu_1st_indv_val          0
# ...

# %%
df.shape
# Out:
# (503, 40)

# %%
df.describe()
# Out:
#         Unnamed: 0  tickets_purchased_qty  trans_face_val_amt      age_yr  \
# count   503.000000             503.000000          503.000000  503.000000
# mean   2568.129225               1.015905           25.130219   44.369048
# std    1481.261013               0.125231           19.935065    9.534705
# min       2.000000               1.000000            5.000000   18.000000
# 25%    1273.500000               1.000000           20.000000   44.369048
# 50%    2598.000000               1.000000           20.000000   44.369048
# 75%    3881.000000               1.000000           25.000000   44.369048
# max    4998.000000               2.000000          240.000000   94.000000
#
#           income_amt  adults_in_hh_num  married_ind  child_present_ind  \
# count     503.000000        503.000000   503.000000         503.000000
# mean    86396.103896          2.579545     0.668790           0.561538
# std     32514.166011          0.880156     0.263205           0.252508
# ...
