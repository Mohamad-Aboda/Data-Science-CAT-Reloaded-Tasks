# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')

# %%
data.head()

# %%
data.info
# Out:
# <bound method DataFrame.info of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
del data['Unnamed: 32']

# %%
mean_data = list(data.columns[1:12])
mean_data
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean']

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize = (10, 10))
sns.heatmap(data[mean_data].corr(), annot = True)
plt.show()
plt.tight_layout()

# %%
mean_data
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean']

# %%
sns.stripplot(x = 'diagnosis', y = 'area_mean', data = data)
plt.show()

# %%
sns.swarmplot(x = 'diagnosis', y = 'area_mean', data = data)

# %%
sns.distplot(data['radius_mean'])

# %%
sns.distplot(data['texture_mean'])

# %%
sns.distplot(data['perimeter_mean'])

# %%
sns.distplot(data['area_mean'])

# %%
sns.distplot(data['smoothness_mean'])

# %%
sns.distplot(data['concavity_mean'])

# %%
sns.distplot(data['fractal_dimension_mean'])

# %%
sns.distplot(data['compactness_mean'])

# %%
sns.distplot(data['concave points_mean'])

# %%
sns.distplot(data['symmetry_mean'])

# %%
mean_data
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean']

# %%
lst = [
 'radius_mean',
 'texture_mean',
 'perimeter_mean',
 'area_mean',
 'smoothness_mean',
 'compactness_mean',
 'concavity_mean',
 'concave points_mean',
 'symmetry_mean',
 'fractal_dimension_mean',
    'radius_mean'
]

j = 1
colors = ['red', 'blue', 'green', 'yellow', 'red', 'blue', 'green', 'yellow', 'red', 'blue', 'red', 'blue']
plt.figure(figsize = (20, 20))

for i in lst:
    sns.scatterplot(data[i], data[i] + 1, color = colors[j])
    plt.subplot(3, 4, j)
    j = j  + 1
    plt.legend(labels = lst)

# %%
lst = [
 'diagnosis',
 'radius_mean',
 'texture_mean',
 'perimeter_mean',
 'area_mean',
 'smoothness_mean',
 'compactness_mean',
 'concavity_mean',
 'concave points_mean',
 'symmetry_mean',
 'fractal_dimension_mean',
    
]

j = 0
for i in lst:
    j = j + 1
    #plt.subplot(5, 2, i + 1)
    sns.boxplot(x = lst[0], y = lst[j], data = data )
    plt.show()
    if j == 10:
        break
