# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headers = ['ID', 'refractive index', 'Sodium oxide', 'magnesium oxide', 
              'aluminum oxide','silcon oxide', 'potassium oxide', 'calcium oxide',
           'barium oxide', 'iron oxide', 'type']
          
df = pd.read_csv('glass.data.csv', names = headers)

# %%
df.head()
# Out:
#    ID  refractive index  Sodium oxide  magnesium oxide  aluminum oxide  \
# 0   1           1.52101         13.64             4.49            1.10
# 1   2           1.51761         13.89             3.60            1.36
# 2   3           1.51618         13.53             3.55            1.54
# 3   4           1.51766         13.21             3.69            1.29
# 4   5           1.51742         13.27             3.62            1.24
#
#    silcon oxide  potassium oxide  calcium oxide  barium oxide  iron oxide  \
# 0         71.78             0.06           8.75           0.0         0.0
# 1         72.73             0.48           7.83           0.0         0.0
# 2         72.99             0.39           7.78           0.0         0.0
# 3         72.61             0.57           8.22           0.0         0.0
# 4         73.08             0.55           8.07           0.0         0.0
#
#    type
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
# ID                  214 non-null int64
# refractive index    214 non-null float64
# Sodium oxide        214 non-null float64
# magnesium oxide     214 non-null float64
# aluminum oxide      214 non-null float64
# silcon oxide        214 non-null float64
# potassium oxide     214 non-null float64
# calcium oxide       214 non-null float64
# barium oxide        214 non-null float64
# iron oxide          214 non-null float64
# type                214 non-null int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.isna().sum()
# Out:
# ID                  0
# refractive index    0
# Sodium oxide        0
# magnesium oxide     0
# aluminum oxide      0
# silcon oxide        0
# potassium oxide     0
# calcium oxide       0
# barium oxide        0
# iron oxide          0
# type                0
# dtype: int64

# %%
# ploting the heat map
plt.style.use('fivethirtyeight')
plt.figure(figsize = (10, 10))
sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
plt.show()
plt.tight_layout()

# %%
headers = list(headers)
headers
# Out:
# ['ID',
#  'refractive index',
#  'Sodium oxide',
#  'magnesium oxide',
#  'aluminum oxide',
#  'silcon oxide',
#  'potassium oxide',
#  'calcium oxide',
#  'barium oxide',
#  'iron oxide',
#  'type']

# %%
# ploting all Histograms for the df 
# for name in headers:
#     if name == 'ID':
#         continue
#     sns.distplot(df[name], kde= True, bins=30)
#     plt.show()

# %%
sns.distplot(df[headers[1]])

# %%
sns.distplot(df[headers[2]])

# %%
sns.distplot(df[headers[3]])

# %%
sns.distplot(df[headers[4]])

# %%
sns.distplot(df[headers[5]])

# %%
sns.distplot(df[headers[6]])

# %%
sns.distplot(df[headers[7]])

# %%
sns.distplot(df[headers[8]])

# %%
sns.distplot(df[headers[9]])

# %%
# we have outliers in K and Br 
# so i gonna try to get red of this outliers
df['type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: type, dtype: int64

# %%
sns.countplot(df['type'])

# %%
headers
# Out:
# ['ID',
#  'refractive index',
#  'Sodium oxide',
#  'magnesium oxide',
#  'aluminum oxide',
#  'silcon oxide',
#  'potassium oxide',
#  'calcium oxide',
#  'barium oxide',
#  'iron oxide',
#  'type']

# %%
for name in headers:
    if name == 'ID':
        continue
    sns.boxplot(df[name])
    plt.show()

# %%
df.describe()
# Out:
#                ID  refractive index  Sodium oxide  magnesium oxide  \
# count  214.000000        214.000000    214.000000       214.000000
# mean   107.500000          1.518365     13.407850         2.684533
# std     61.920648          0.003037      0.816604         1.442408
# min      1.000000          1.511150     10.730000         0.000000
# 25%     54.250000          1.516523     12.907500         2.115000
# 50%    107.500000          1.517680     13.300000         3.480000
# 75%    160.750000          1.519157     13.825000         3.600000
# max    214.000000          1.533930     17.380000         4.490000
#
#        aluminum oxide  silcon oxide  potassium oxide  calcium oxide  \
# count      214.000000    214.000000       214.000000     214.000000
# mean         1.444907     72.650935         0.497056       8.956963
# std          0.499270      0.774546         0.652192       1.423153
# min          0.290000     69.810000         0.000000       5.430000
# ...

# %%
for name in headers:
    print(name, end = ' skewness = ')
    print(df[name].skew())
# Out:
# ID skewness = 0.0
# refractive index skewness = 1.625430506008766
# Sodium oxide skewness = 0.4541814536577495
# magnesium oxide skewness = -1.1525593175802356
# aluminum oxide skewness = 0.9072898090246346
# silcon oxide skewness = -0.7304472251318588
# potassium oxide skewness = 6.55164830960496
# calcium oxide skewness = 2.0470539131183103
# barium oxide skewness = 3.4164245693025577
# iron oxide skewness = 1.754327470435831
# type skewness = 1.114915200905486

# %%
# as we see (posassium & barium & iron & calcuim) has outliers
# so i will try to deal with outliers soon 
headers
# Out:
# ['ID',
#  'refractive index',
#  'Sodium oxide',
#  'magnesium oxide',
#  'aluminum oxide',
#  'silcon oxide',
#  'potassium oxide',
#  'calcium oxide',
#  'barium oxide',
#  'iron oxide',
#  'type']

# %%
# print(df['potassium oxide'].quantile(0.20))
# print(df['potassium oxide'].quantile(0.80))

# print(df['iron oxide'].quantile(0.20))
# print(df['iron oxide'].quantile(0.80))

# print(df['barium oxide'].quantile(.2))
# print(df['barium oxide'].quantile(.8))

# print(df['calcium oxide'].quantile(.2))
# print(df['calcium oxide'].quantile(.8))

# %%
cop_data = df

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

print(cop_data.shape)
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_out.shape)
# Out:
# (214, 11)
# (136, 11)

# %%
for name in headers:
    print(name, end = ' Has skewness equal >>  ')
    print(df_out[name].skew())
# Out:
# ID Has skewness equal >>  0.1421912667883587
# refractive index Has skewness equal >>  1.052989735041804
# Sodium oxide Has skewness equal >>  0.8431158194735793
# magnesium oxide Has skewness equal >>  -3.404660450576473
# aluminum oxide Has skewness equal >>  -0.10064431896904599
# silcon oxide Has skewness equal >>  -0.47699274373079076
# potassium oxide Has skewness equal >>  -1.0229152049967336
# calcium oxide Has skewness equal >>  0.808199862513418
# barium oxide Has skewness equal >>  0
# iron oxide Has skewness equal >>  1.3952428972025888
# type Has skewness equal >>  2.1228053213605516

# %%
df_out['type'] = df_out["type"].map(lambda i: np.log(i) if i > 0 else 0) 
df_out['iron oxide'] =  df_out["iron oxide"].map(lambda i: np.log(i) if i > 0 else 0)
# Out:
# F:\anaconda_installation\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# F:\anaconda_installation\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for name in headers:
    print(name, end = ' Has skewness equal >>  ')
    print(df_out[name].skew())
# Out:
# ID Has skewness equal >>  0.1421912667883587
# refractive index Has skewness equal >>  1.052989735041804
# Sodium oxide Has skewness equal >>  0.8431158194735793
# magnesium oxide Has skewness equal >>  -3.404660450576473
# aluminum oxide Has skewness equal >>  -0.10064431896904599
# silcon oxide Has skewness equal >>  -0.47699274373079076
# potassium oxide Has skewness equal >>  -1.0229152049967336
# calcium oxide Has skewness equal >>  0.808199862513418
# barium oxide Has skewness equal >>  0
# iron oxide Has skewness equal >>  -1.1044303684412828
# type Has skewness equal >>  0.662425453324561

# %%
for name in headers:
    if name == "ID":
        continue
    sns.distplot(df[name])
    plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pairplot(df[headers],palette='coolwarm')
plt.show()

# %%
# i think data seems good right now 
# it's time to fit the model

# %%
X  = df.drop('type',axis=1)
y = df['type']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)
pred
# Out:
# array([1, 7, 1, 7, 2, 2, 1, 2, 2, 2, 6, 5, 2, 2, 6, 5, 7, 1, 1, 6, 2, 7,
#        7, 7, 3, 2, 1, 1, 6, 1, 1, 2, 3, 2, 2, 7, 5, 3, 2, 2, 2, 7, 1, 2,
#        3, 2, 2, 2, 2, 2, 1, 1, 2, 2, 1, 1, 7, 2, 5, 1, 1, 2, 1, 7, 5],
#       dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# [[17  2  0  0  0  0]
#  [ 0 23  0  0  0  0]
#  [ 0  0  4  0  0  0]
#  [ 0  0  0  5  1  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0 10]]
#
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.89      0.94        19
#            2       0.92      1.00      0.96        23
#            3       1.00      1.00      1.00         4
#            5       1.00      0.83      0.91         6
#            6       0.75      1.00      0.86         3
#            7       1.00      1.00      1.00        10
#
#     accuracy                           0.95        65
#    macro avg       0.94      0.95      0.94        65
# weighted avg       0.96      0.95      0.95        65

# %%
error_rate = []
for i in range(1,60):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    predict = knn.predict(X_test)
    error_rate.append(np.mean(predict != y_test))

# %%
plt.figure(figsize=(10,8))
plt.plot(range(len(error_rate)),error_rate,marker='o',markerfacecolor='red',linestyle='--')

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
predict = knn.predict(X_test)

# %%
a = knn.score(X_train,y_train)
b = knn.score(X_test, y_test)
print(a)
print(b)
# Out:
# 0.9932885906040269
# 0.9846153846153847

# %%
from sklearn.metrics import accuracy_score
print("Accuracy {}".format(accuracy_score(y_test, predict)))
# Out:
# Accuracy 0.9846153846153847

# %%
print(confusion_matrix(y_test,predict))
print('\n')
print(classification_report(y_test,predict))
# Out:
# [[18  1  0  0  0  0]
#  [ 0 23  0  0  0  0]
#  [ 0  0  4  0  0  0]
#  [ 0  0  0  6  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0 10]]
#
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.97        19
#            2       0.96      1.00      0.98        23
#            3       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         6
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00        10
#
#     accuracy                           0.98        65
#    macro avg       0.99      0.99      0.99        65
# weighted avg       0.99      0.98      0.98        65

# %%
plt.figure(figsize=(8,6))
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,predict)),annot=True,cmap='magma',cbar=False,linewidths=1,fmt='.3g')
